# %% [markdown]
# <a href="https://colab.research.google.com/github/duartedani/tbh-esportes-estudos/blob/main/02_06_ETL_extracao_base_TBH_Esportes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### 1º - Instalação de Bibliotecas
#
#  **boto3**
# - É o SDK oficial da AWS para Python
# - Serve para acessar serviços da Amazon:
#   - S3
#   - Lambda
#   - DynamoDB
#   - Entre outros
#
#  **camelot-py**
# - Biblioteca especializada em extração de tabelas de PDFs
# - Principais funcionalidades:
#   - Leitura de arquivos PDF
#   - Detecção automática de tabelas
#   - Conversão para DataFrame (formato semelhante a Excel/CSV)
#
#  **pandas**
# - Biblioteca padrão para análise de dados em Python
# - Utilizada para:
#   - Manipulação de tabelas
#   - Tratamento de dados
#   - Exportação para CSV, Excel e outros formatos

# %%
# !pip install boto3 camelot-py pandas
# !pip install awscli
# Out:
# Collecting boto3
#   Using cached boto3-1.43.19-py3-none-any.whl.metadata (6.6 kB)
# Collecting camelot-py
#   Using cached camelot_py-1.0.9-py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Collecting botocore<1.44.0,>=1.43.19 (from boto3)
#   Downloading botocore-1.43.19-py3-none-any.whl.metadata (5.6 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.1.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.19.0,>=0.18.0 (from boto3)
#   Downloading s3transfer-0.18.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: click>=8.0.1 in /usr/local/lib/python3.12/dist-packages (from camelot-py) (8.4.0)
# Requirement already satisfied: chardet>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from camelot-py) (5.2.0)
# Requirement already satisfied: numpy>=1.26.1 in /usr/local/lib/python3.12/dist-packages (from camelot-py) (2.0.2)
# Requirement already satisfied: openpyxl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from camelot-py) (3.1.5)
# Collecting pdfminer-six>=20240706 (from camelot-py)
#   Downloading pdfminer_six-20260107-py3-none-any.whl.metadata (4.3 kB)
# Collecting pypdf<6.0,>=4.0 (from camelot-py)
#   Downloading pypdf-5.9.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: tabulate>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from camelot-py) (0.9.0)
# Requirement already satisfied: opencv-python-headless>=4.7.0.68 in /usr/local/lib/python3.12/dist-packages (from camelot-py) (4.13.0.92)
# Collecting pypdfium2>=4 (from camelot-py)
#   Downloading pypdfium2-5.9.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.4/68.4 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: pillow>=10.4.0 in /usr/local/lib/python3.12/dist-packages (from camelot-py) (11.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.12/dist-packages (from botocore<1.44.0,>=1.43.19->boto3) (2.5.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl>=3.1.0->camelot-py) (2.0.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer-six>=20240706->camelot-py) (3.4.7)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer-six>=20240706->camelot-py) (48.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from cryptography>=36.0.0->pdfminer-six>=20240706->camelot-py) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0.0->cryptography>=36.0.0->pdfminer-six>=20240706->camelot-py) (3.0)
# Downloading boto3-1.43.19-py3-none-any.whl (140 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.5/140.5 kB 9.7 MB/s eta 0:00:00
# Downloading camelot_py-1.0.9-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.9 MB/s eta 0:00:00
# Downloading botocore-1.43.19-py3-none-any.whl (15.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 86.1 MB/s eta 0:00:00
# Downloading jmespath-1.1.0-py3-none-any.whl (20 kB)
# Downloading pdfminer_six-20260107-py3-none-any.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 102.7 MB/s eta 0:00:00
# Downloading pypdf-5.9.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.2/313.2 kB 27.8 MB/s eta 0:00:00
# Downloading pypdfium2-5.9.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 98.0 MB/s eta 0:00:00
# Downloading s3transfer-0.18.0-py3-none-any.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.6/88.6 kB 9.0 MB/s eta 0:00:00
# Installing collected packages: pypdfium2, pypdf, jmespath, botocore, s3transfer, pdfminer-six, camelot-py, boto3
# Successfully installed boto3-1.43.19 botocore-1.43.19 camelot-py-1.0.9 jmespath-1.1.0 pdfminer-six-20260107 pypdf-5.9.0 pypdfium2-5.9.0 s3transfer-0.18.0
# Collecting awscli
#   Using cached awscli-1.45.19-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: botocore==1.43.19 in /usr/local/lib/python3.12/dist-packages (from awscli) (1.43.19)
# Collecting docutils<=0.19,>=0.18.1 (from awscli)
#   Downloading docutils-0.19-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: s3transfer<0.19.0,>=0.18.0 in /usr/local/lib/python3.12/dist-packages (from awscli) (0.18.0)
# Requirement already satisfied: PyYAML<6.1,>=3.10 in /usr/local/lib/python3.12/dist-packages (from awscli) (6.0.3)
# Collecting colorama<0.4.7,>=0.2.5 (from awscli)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting rsa<4.8,>=3.1.2 (from awscli)
#   Downloading rsa-4.7.2-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from botocore==1.43.19->awscli) (1.1.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.12/dist-packages (from botocore==1.43.19->awscli) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.12/dist-packages (from botocore==1.43.19->awscli) (2.5.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.12/dist-packages (from rsa<4.8,>=3.1.2->awscli) (0.6.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore==1.43.19->awscli) (1.17.0)
# Downloading awscli-1.45.19-py3-none-any.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 63.0 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading docutils-0.19-py3-none-any.whl (570 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 570.5/570.5 kB 43.5 MB/s eta 0:00:00
# Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Installing collected packages: rsa, docutils, colorama, awscli
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.9.1
#     Uninstalling rsa-4.9.1:
#       Successfully uninstalled rsa-4.9.1
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.21.2
#     Uninstalling docutils-0.21.2:
#       Successfully uninstalled docutils-0.21.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sphinx 8.2.3 requires docutils<0.22,>=0.20, but you have docutils 0.19 which is incompatible.
# Successfully installed awscli-1.45.19 colorama-0.4.6 docutils-0.19 rsa-4.7.2

# %%
# !aws --version
# Out:
# aws-cli/1.45.19 Python/3.12.13 Linux/6.6.122+ botocore/1.43.19

# %%
# !aws configure
# Out:
# AWS Access Key ID [None]: AKIAR4JOHZODKT3SLYQ6
# AWS Secret Access Key [None]: 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
# Default region name [None]: us-east-1
# Default output format [None]: json

# %%
# !aws sts get-caller-identity
# Out:
# {
#     "UserId": "AIDAR4JOHZODOO6BOIAMJ",
#     "Account": "129482869638",
#     "Arn": "arn:aws:iam::129482869638:user/user_estudos_ia"
# }

# %% [markdown]
# #### 2º - Importação das bibliotecas
#
#     import boto3
#         - baixar PDF de um bucket S3
#         - listar arquivos na nuvem
#         - enviar CSV processado de volta
#
#     import camelot
#         - ler PDFs com tabelas
#         - extrair dados estruturados (tipo planilha)
#         - converter tabelas do PDF em DataFrame
#
#     import pandas as pd
#         - manipular tabelas (DataFrame)
#         - limpar dados
#         - salvar CSV
#
#     import re
#         - biblioteca de expressões regulares
#         - limpar textos
#         - remover caracteres estranhos do PDF
#         - extrair padrões (ex: números, datas, nomes)
#
#     import os
#         - trabalha em pastas e arquivos
#         - criar diretórios
#         - verificar se arquivos existem
#         - trabalhar com caminhos

# %%
import boto3
import camelot
from tqdm import tqdm
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.width', 200)
pd.set_option('display.max_colwidth', None)

import re
import os
import io

# %% [markdown]
# #### 3º - Conexão com AWS S3
#
#     - Define as credenciais de autenticação
#     - S3 → objeto que fala com a AWS
#     - bucket → pasta onde estão os PDFs
#     Colocando as credencias:
#
#         Será solicitado:
#             - access_key
#             - secret_key
#             - region
#             - output format

# %%
# !aws configure list
# Out:
#       Name                    Value             Type    Location
#       ----                    -----             ----    --------
#    profile                <not set>             None    None
# access_key     ****************LYQ6 shared-credentials-file
# secret_key     ****************b3N8 shared-credentials-file
#     region                us-east-1      config-file    ~/.aws/config

# %%
s3 = boto3.client("s3")

# %%
s3 = boto3.client("s3")

response = s3.list_buckets()
print(response["Buckets"])
# Out:
# [{'Name': 'amazon-sagemaker-129482869638-us-east-1-5ko1rs8slirgrr', 'CreationDate': datetime.datetime(2026, 5, 20, 13, 25, 54, tzinfo=tzlocal()), 'BucketArn': 'arn:aws:s3:::amazon-sagemaker-129482869638-us-east-1-5ko1rs8slirgrr'}, {'Name': 'bucket-estudo-aws-danielle-duarte', 'CreationDate': datetime.datetime(2026, 1, 13, 21, 58, 25, tzinfo=tzlocal()), 'BucketArn': 'arn:aws:s3:::bucket-estudo-aws-danielle-duarte'}, {'Name': 'tbh-resultados-raw', 'CreationDate': datetime.datetime(2026, 5, 5, 14, 4, 12, tzinfo=tzlocal()), 'BucketArn': 'arn:aws:s3:::tbh-resultados-raw'}, {'Name': 'tbh-resultados-silver', 'CreationDate': datetime.datetime(2026, 5, 20, 12, 53, 35, tzinfo=tzlocal()), 'BucketArn': 'arn:aws:s3:::tbh-resultados-silver'}, {'Name': 'tbh-resultados-teste', 'CreationDate': datetime.datetime(2026, 5, 21, 19, 18, 35, tzinfo=tzlocal()), 'BucketArn': 'arn:aws:s3:::tbh-resultados-teste'}, {'Name': 'tbh-resultados-teste-2', 'CreationDate': datetime.datetime(2026, 5, 22, 17, 55, 57, tzinfo=tzlocal()), 'BucketArn': 'arn:aws:s3:::tbh-resultados-teste-2'}]

# %%
s3.list_objects_v2(Bucket="tbh-resultados-raw")
# Out:
# {'ResponseMetadata': {'RequestId': 'TVDMQ3MYWT135A4E',
#   'HostId': '3dPk1+EtmAhQ7tyyVjczmHOmu4aqK94+SxjbBvAqnI8KO7WtKWXqHT4t4HTboDhplEJkn0hPl6f4ts+c3heUdlo2Z4t0YDyY',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2':
pdf',
#    'LastModified': datetime.datetime(2026, 5, 11, 20, 25, 6, tzinfo=tzlocal()),
#    'ETag': '"e45e2b182a02203e800bb63070a6a574"',
#    'ChecksumAlgorithm': ['CRC64NVME'],
#    'ChecksumType': 'FULL_OBJECT',
#    'Size': 48320,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'TBH Esportes/corridas_2026_completo_final/2026-04-26_Corrida_do_Exercito_2026_5km-feminino-geral.pdf',
#    'LastModified': datetime.datetime(2026, 5, 11, 20, 25, 7, tzinfo=tzlocal()),
#    'ETag': '"ab69119cc3b10662ad2a436a05b66920"',
#    'ChecksumAlgorithm': ['CRC64NVME'],
#    'ChecksumType': 'FULL_OBJECT',
#    'Size': 331212,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'TBH Esportes/corridas_2026_completo_final/2026-04-26_Corrida_do_Exercito_2026_5km-feminino-militar.pdf',
#    'LastModified': datetime.datetime(2026, 5, 11, 20, 25, 8, tzinfo=tzlocal()),
#    'ETag': '"567335bbbcde89b7ab60ec71e5377376"',
#    'ChecksumAlgorithm': ['CRC64NVME'],
#    'ChecksumType': 'FULL_OBJECT',
#    'Size': 37849,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'TBH Esportes/corridas_2026_completo_final/2026-04-26_Corrida_do_Exercito_2026_5km-masculino-geral.pdf',
#    'LastModified': datetime.datetime(2026, 5, 11, 20, 25, 9, tzinfo=tzlocal()),
#    'ETag': '"dfe824ad28e1b4950cb40985fc428e8e"',
#    'ChecksumAlgorithm': ['CRC64NVME'],
#    'ChecksumType': 'FULL_OBJECT',
#    'Size': 307953,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'TBH Esportes/corridas_2026_completo_final/2026-04-26_Corrida_do_Exercito_2026_5km-masculino-militar.pdf',
#    'LastModified': datetime.datetime(2026, 5, 11, 20, 25, 10, tzinfo=tzlocal()),
#    'ETag': '"1f3121f00bda0fbb1391883ec5f66de0"',
#    'ChecksumAlgorithm': ['CRC64NVME'],
#    'ChecksumType': 'FULL_OBJECT',
#    'Size': 151681,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'TBH Esportes/corridas_2026_completo_final/2026-05-03_Corrida_do_América_2026_GERAL-DUATLHON-REVEZAMENTO.pdf',
#    'LastModified': datetime.datetime(2026, 5, 11, 20, 25, 24, tzinfo=tzlocal()),
#    'ETag': '"185a48909f7d81f158630ce7407c494c"',
#    'ChecksumAlgorithm': ['CRC64NVME'],
#    'ChecksumType': 'FULL_OBJECT',
#    'Size': 6012,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'TBH Esportes/corridas_2026_completo_final/2026-05-03_Corrida_do_América_2026_GERAL-DUATLHON-SIMPLES-FEMININO.pdf',
#    'LastModified': datetime.datetime(2026, 5, 11, 20, 25, 25, tzinfo=tzlocal()),
#    'ETag': '"b3a7e87e9f69dfddbb35b48e815194f1"',
#    'ChecksumAlgorithm': ['CRC64NVME'],
#    'ChecksumType': 'FULL_OBJECT',
#    'Size': 11574,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'TBH Esportes/corridas_2026_completo_final/2026-05-03_Corrida_do_América_2026_GERAL-DUATLHON-SIMPLES-MASCULINO-1.pdf',
#    'LastModified': datetime.datetime(2026, 5, 11, 20, 25, 25, tzinfo=tzlocal()),
#    'ETag': '"fb1e252dea31bc3f1a5e8d78cb304b22"',
#    'ChecksumAlgorithm': ['CRC64NVME'],
#    'ChecksumType': 'FULL_OBJECT',
#    'Size': 27846,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'TBH Esportes/corridas_2026_completo_final/2026-05-03_Corrida_do_América_2026_GERAL-FEMININO-10KM.pdf',
#    'LastModified': datetime.datetime(2026, 5, 11, 20, 25, 27, tzinfo=tzlocal()),
#    'ETag': '"11885a6a4ebd54890e0ce5c7dfa8ee9a"',
#    'ChecksumAlgorithm': ['CRC64NVME'],
#    'ChecksumType': 'FULL_OBJECT',
#    'Size': 8101,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'TBH Esportes/corridas_2026_completo_final/2026-05-03_Corrida_do_América_2026_GERAL-FEMININO-15KM.pdf',
#    'LastModified': datetime.datetime(2026, 5, 11, 20, 25, 27, tzinfo=tzlocal()),
#    'ETag': '"672d2839753f67ac9cd7559bb11728c1"',
#    'ChecksumAlgorithm': ['CRC64NVME'],
#    'ChecksumType': 'FULL_OBJECT',
#    'Size': 3082,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'TBH Esportes/corridas_2026_completo_final/2026-05-03_Corrida_do_América_2026_GERAL-FEMININO-5KM.pdf',
#    'LastModified': datetime.datetime(2026, 5, 11, 20, 25, 28, tzinfo=tzlocal()),
#    'ETag': '"6e943f6ac7e2bb7aa80a5a54363f457e"',
#    'ChecksumAlgorithm': ['CRC64NVME'],
#    'ChecksumType': 'FULL_OBJECT',
#    'Size': 59944,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'TBH Esportes/corridas_2026_completo_final/2026-05-03_Corrida_do_América_2026_GERAL-MASCULINO-10KM.pdf',
#    'LastModified': datetime.datetime(2026, 5, 11, 20, 25, 28, tzinfo=tzlocal()),
#    'ETag': '"61fd9dafb8bf5a0e1bad3fb55e0e3a9c"',
#    'ChecksumAlgorithm': ['CRC64NVME'],
#    'ChecksumType': 'FULL_OBJECT',
#    'Size': 25268,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'TBH Esportes/corridas_2026_completo_final/2026-05-03_Corrida_do_América_2026_GERAL-MASCULINO-15KM.pdf',
#    'LastModified': datetime.datetime(2026, 5, 11, 20, 25, 29, tzinfo=tzlocal()),
#    'ETag': '"b6666812b4406a0b3213693843e61d7f"',
#    'ChecksumAlgorithm': ['CRC64NVME'],
#    'ChecksumType': 'FULL_OBJECT',
#    'Size': 14817,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'TBH Esportes/corridas_2026_completo_final/2026-05-03_Corrida_do_América_2026_GERAL-MASCULINO-5KM.pdf',
#    'LastModified': datetime.datetime(2026, 5, 11, 20, 25, 30, tzinfo=tzlocal()),
#    'ETag': '"a761055b655b0489d6f79383dd169bf5"',
#    'ChecksumAlgorithm': ['CRC64NVME'],
#    'ChecksumType': 'FULL_OBJECT',
#    'Size': 153658,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'TBH Esportes/corridas_2026_completo_final/2026-05-03_corridaotempo_10KM_FEMININO.pdf',
#    'LastModified': datetime.datetime(2026, 5, 11, 20, 25, 21, tzinfo=tzlocal()),
#    'ETag': '"b42b1742d1c15c78894d4c215ef2781d"',
#    'ChecksumAlgorithm': ['CRC64NVME'],
#    'ChecksumType': 'FULL_OBJECT',
#    'Size': 41959,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'TBH Esportes/corridas_2026_completo_final/2026-05-03_corridaotempo_10KM_MASCULINO.pdf',
#    'LastModified': datetime.datetime(2026, 5, 11, 20, 25, 22, tzinfo=tzlocal()),
#    'ETag': '"40bc15c00ed6ae431a760dbd868e1b88"',
#    'ChecksumAlgorithm': ['CRC64NVME'],
#    'ChecksumType': 'FULL_OBJECT',
#    'Size': 62738,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'TBH Esportes/corridas_2026_completo_final/2026-05-03_corridaotempo_5KM_FEMININO.pdf',
#    'LastModified': datetime.datetime(2026, 5, 11, 20, 25, 23, tzinfo=tzlocal()),
#    'ETag': '"d0f863e2fe9ee6a7dd902c68bcb1cc35"',
#    'ChecksumAlgorithm': ['CRC64NVME'],
#    'ChecksumType': 'FULL_OBJECT',
#    'Size': 307062,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'TBH Esportes/corridas_2026_completo_final/2026-05-03_corridaotempo_5KM_MASCULINO.pdf',
#    'LastModified': datetime.datetime(2026, 5, 11, 20, 25, 24, tzinfo=tzlocal()),
#    'ETag': '"f1ada8f5f85368a2c24b542613eeaaae"',
#    'ChecksumAlgorithm': ['CRC64NVME'],
#    'ChecksumType': 'FULL_OBJECT',
#    'Size': 189016,
#    'StorageClass': 'STANDARD'}],
#  'Name': 'tbh-resultados-raw',
#  'Prefix': '',
#  'MaxKeys': 1000,
#  'EncodingType': 'url',
#  'KeyCount': 117}

# %% [markdown]
# #### 4º - Transformar o nome do arquivo em dados estruturados
#
#         - Obtem os metadados da corrida e que serão adicionados na estrutura da tabela posteriormente.
#         - Dados obtidos:
#              - nome da corrida,
#              - ano
#              - genero
#              - distancia da prova

# %%
def extrair_metadados(key):
    filename = os.path.basename(key).replace('.pdf', '')

    # 📅 Data
    data_match = re.search(r'\d{4}-\d{2}-\d{2}', filename)
    data = data_match.group(0) if data_match else None

    # 🏃 Corrida (entre data e ano)
    corrida_match = re.search(r'\d{4}-\d{2}-\d{2}_(.+?)_\d{4}', filename)
    corrida = corrida_match.group(1) if corrida_match else None

    # 🚻 + 📏 Distância (dois padrões possíveis)

    # Padrão 1: 06KM-FEMININO
    pattern1 = r'(?P<dist>\d+(?:\.\d+)?)KM-(?P<gen>FEMININO|MASCULINO)'

    # Padrão 2: FEMININO-12.8KM
    pattern2 = r'(?P<gen>FEMININO|MASCULINO)-(?P<dist>\d+(?:\.\d+)?)KM'

    match = re.search(pattern1, filename, re.IGNORECASE)

    if not match:
        match = re.search(pattern2, filename, re.IGNORECASE)

    if match:
        genero = match.group('gen').upper()
        distancia = float(match.group('dist'))
    else:
        genero = None
        distancia = None

    return {
        'data': data,
        'corrida': corrida,
        'genero': genero,
        'distancia_km': distancia
    }

# %% [markdown]
# ##### GUIA : Identificar o nome nome dos arquivos no S3

# %%
bucket = "tbh-resultados-raw"
prefix = "TBH Esportes/corridas_2026_completo_final/"

# %%
def listar_arquivos_s3(s3, bucket, prefixo=None):
    arquivos = []

    kwargs = {'Bucket': bucket}
    if prefixo:
        kwargs['Prefix'] = prefixo

    while True:
        response = s3.list_objects_v2(**kwargs)

        for obj in response.get('Contents', []):
            arquivos.append(obj['Key'])

        # verifica se tem mais páginas
        if response.get('IsTruncated'):
            kwargs['ContinuationToken'] = response['NextContinuationToken']
        else:
            break

    return arquivos

# %%
keys = listar_arquivos_s3(s3, bucket)

print("Total de arquivos:", len(keys))

print("\nPrimeiros 5 arquivos:\n")
for i, k in enumerate(keys[:5], 1):
    print(f"{i} - {k}")
# Out:
# Total de arquivos: 117
#
# Primeiros 5 arquivos:
#
# 1 - TBH Esportes/corridas_2026_completo_final/2026-01-25_Park_Run_2026_06KM-FEMININO-1.pdf
# 2 - TBH Esportes/corridas_2026_completo_final/2026-01-25_Park_Run_2026_06KM-MASCULINO.pdf
# 3 - TBH Esportes/corridas_2026_completo_final/2026-01-25_Park_Run_2026_09KM-FEMININO.pdf
# 4 - TBH Esportes/corridas_2026_completo_final/2026-01-25_Park_Run_2026_09KM-MASCULINO.pdf
# 5 - TBH Esportes/corridas_2026_completo_final/2026-02-01_Ouro_Verde_Run_2026_FEMININO-12.8KM-1.pdf

# %% [markdown]
# ##### EXEMPLO : Obter o nome de 1 arquivo para validação

# %%
key = "TBH Esportes/corridas_2026_completo_final/2026-01-25_Park_Run_2026_09KM-FEMININO"

# %% [markdown]
# ###### VALIDAÇÃO : Verificar como os dados referente a corrida estão retornando

# %%
extrair_metadados(key)
# Out:
# {'data': '2026-01-25',
#  'corrida': 'Park_Run',
#  'genero': 'FEMININO',
#  'distancia_km': 9.0}

# %% [markdown]
# #### 5º - Coleta os arquivos do S3 e retorna apenas o que é PDF
#
#
#     - Percorre todos os arquivos do bucket/pasta no S3
#     - Lida com paginação (caso tenha muitos arquivos)
#     - Filtra apenas PDFs
#     - Guarda tudo numa lista - pdf_keys

# %%
paginator = s3.get_paginator('list_objects_v2')

pdf_keys = []

for page in paginator.paginate(Bucket=bucket, Prefix=prefix):
    contents = page.get('Contents', [])

    for obj in contents:
        key = obj['Key']

        # garante que só pega PDFs reais (evita zip etc.)
        if key.lower().endswith('.pdf'):
            pdf_keys.append(key)

print(f"Total de PDFs encontrados: {len(pdf_keys)}")
# Out:
# Total de PDFs encontrados: 117

# %% [markdown]
# #### 6º - Normalização dos cabeçalhos

# %%
arquivos_pdf = []

for key in pdf_keys:
    obj = s3.get_object(Bucket=bucket, Key=key)
    pdf_bytes = obj['Body'].read()

    arquivos_pdf.append({
        "key": key,
        "pdf_bytes": pdf_bytes
    })

print("Arquivos carregados:", len(arquivos_pdf))
# Out:
# Arquivos carregados: 117

# %%
from tqdm import tqdm
cabecalhos = []

for arq in tqdm(arquivos_pdf, desc="Processando PDFs"):
    try:
        obj = s3.get_object(Bucket=bucket, Key=arq["key"])
        pdf_bytes = obj["Body"].read()

        tables = camelot.read_pdf(io.BytesIO(pdf_bytes))

        if len(tables) == 0:
            continue

        df = tables[0].df
        header = tuple(df.iloc[0].astype(str).str.strip().tolist())

        cabecalhos.append({
            "key": arq["key"],
            "cabecalho": header
        })

    except Exception as e:
        print("Erro no arquivo:", arq["key"], e)
# Out:
# Processando PDFs: 100%|██████████| 117/117 [03:12<00:00,  1.65s/it]

# %%
df.columns = df.iloc[0]
df = df[1:].reset_index(drop=True)

# %%
#s3 = boto3.client('s3')
#bucket = "tbh-resultados-raw"
#prefix = "TBH Esportes/corridas_2026_completo_final/"

def listar_arquivos_s3(s3_client, bucket_name, prefixo=None):
    arquivos = []
    kwargs = {'Bucket': bucket_name}
    if prefixo:
        kwargs['Prefix'] = prefixo

    while True:
        response = s3_client.list_objects_v2(**kwargs)
        for obj in response.get('Contents', []):
            arquivos.append(obj['Key'])
        if response.get('IsTruncated'):
            kwargs['ContinuationToken'] = response['NextContinuationToken']
        else:
            break
    return arquivos

pdf_keys = listar_arquivos_s3(s3, bucket, prefix)

cabecalhos = []
not_processed_pdfs = []

for key in tqdm(pdf_keys, desc="Processando PDFs"):
    try:
        obj = s3.get_object(Bucket=bucket, Key=key)
        pdf_bytes = obj['Body'].read()

        tables = camelot.read_pdf(io.BytesIO(pdf_bytes))

        if len(tables) == 0:
            print(f"Aviso: Nenhum cabeçalho encontrado no PDF (sem tabelas): {key}")
            not_processed_pdfs.append(key)
            continue

        df = tables[0].df
        header = tuple(df.iloc[0].astype(str).str.strip().tolist())

        cabecalhos.append({
            "key": key,
            "cabecalho": header
        })

    except Exception as e:
        print(f"Erro ao processar o arquivo: {key} - {e}")
        not_processed_pdfs.append(key)

print(f"Total de PDFs no S3: {len(pdf_keys)}")
print(f"Cabeçalhos coletados: {len(cabecalhos)}")
print(f"PDFs não processados: {len(not_processed_pdfs)}")

if not_processed_pdfs:
    print("Lista de PDFs não processados:")
    for pdf in not_processed_pdfs:
        print(pdf)

from collections import Counter

contagem = Counter([item["cabecalho"] for item in cabecalhos])

print("Tipos de cabeçalho:", len(contagem))

for i, (cab, qtd) in enumerate(contagem.items()):
    print(f"\n=== Tipo {i+1} ({qtd} arquivos) ===")
    print(cab)
# Out:
# Processando PDFs:  37%|███▋      | 43/117 [01:11<02:06,  1.71s/it]
# Aviso: Nenhum cabeçalho encontrado no PDF (sem tabelas): TBH Esportes/corridas_2026_completo_final/2026-03-15_Corrida_Divas_na_Pista_2026_5KM-FEMININO.pdf
# Processando PDFs:  60%|█████▉    | 70/117 [01:56<01:07,  1.44s/it]
# Aviso: Nenhum cabeçalho encontrado no PDF (sem tabelas): TBH Esportes/corridas_2026_completo_final/2026-04-12_Corrida_Farid_2026_-_Etapa_Ouro_Branco_COLABORADORES-10KM-MASCULINO.pdf
# Processando PDFs:  62%|██████▏   | 72/117 [01:58<00:48,  1.08s/it]
# Aviso: Nenhum cabeçalho encontrado no PDF (sem tabelas): TBH Esportes/corridas_2026_completo_final/2026-04-12_Corrida_Farid_2026_-_Etapa_Ouro_Branco_COLABORADORES-5KM-MASCULINO.pdf
# Processando PDFs:  93%|█████████▎| 109/117 [02:58<00:10,  1.36s/it]
# Aviso: Nenhum cabeçalho encontrado no PDF (sem tabelas): TBH Esportes/corridas_2026_completo_final/2026-05-03_Corrida_do_América_2026_GERAL-FEMININO-15KM.pdf
# Processando PDFs: 100%|██████████| 117/117 [03:12<00:00,  1.64s/it]
# Total de PDFs no S3: 117
# Cabeçalhos coletados: 113
# PDFs não processados: 4
# Lista de PDFs não processados:
# TBH Esportes/corridas_2026_completo_final/2026-03-15_Corrida_Divas_na_Pista_2026_5KM-FEMININO.pdf
# TBH Esportes/corridas_2026_completo_final/2026-04-12_Corrida_Farid_2026_-_Etapa_Ouro_Branco_COLABORADORES-10KM-MASCULINO.pdf
# TBH Esportes/corridas_2026_completo_final/2026-04-12_Corrida_Farid_2026_-_Etapa_Ouro_Branco_COLABORADORES-5KM-MASCULINO.pdf
# TBH Esportes/corridas_2026_completo_final/2026-05-03_Corrida_do_América_2026_GERAL-FEMININO-15KM.pdf
# Tipos de cabeçalho: 3
#
# === Tipo 1 (108 arquivos) ===
# ('Coloc.', 'Num.', 'Nome', 'Sx.', 'Idd.', 'Faixa', 'Cl.Fx.', 'Equipe', 'Tempo', 'Liquido')
#
# === Tipo 2 (2 arquivos) ===
# ('Coloc.', 'Numero', 'Nome', 'Id.', 'Fx.Et.', 'Cl.Fx.', 'Sx.', 'C.', 'Equipe', 'Tempo')
#
# === Tipo 3 (3 arquivos) ===
# ('Coloc.', 'Número', 'Nome', 'Id.', 'Faixa', 'C.F.', 'Equipe', 'Corrida', 'Ciclismo', 'Corrida', 'Tempo')

# %%
# confirmar a variacao de cabeçalhos
len(set(cabecalhos[i]["cabecalho"] for i in range(len(cabecalhos))))
# Out:
# 3

# %%
# Listar exemplos para cada tipo de cabeçalho
for i, (cab, qtd) in enumerate(contagem.items()):
    print(f"\n=== Tipo {i+1} ({qtd} arquivos) ===")
    print(f"Cabeçalho: {cab}")

    # Encontrar os primeiros 3 arquivos deste tipo
    exemplos = [item["key"] for item in cabecalhos if item["cabecalho"] == cab][:3]
    for ex in exemplos:
        print(f"  - {ex}")
# Out:
# === Tipo 1 (108 arquivos) ===
# Cabeçalho: ('Coloc.', 'Num.', 'Nome', 'Sx.', 'Idd.', 'Faixa', 'Cl.Fx.', 'Equipe', 'Tempo', 'Liquido')
#   - TBH Esportes/corridas_2026_completo_final/2026-01-25_Park_Run_2026_06KM-FEMININO-1.pdf
#   - TBH Esportes/corridas_2026_completo_final/2026-01-25_Park_Run_2026_06KM-MASCULINO.pdf
#   - TBH Esportes/corridas_2026_completo_final/2026-01-25_Park_Run_2026_09KM-FEMININO.pdf
#
# === Tipo 2 (2 arquivos) ===
# Cabeçalho: ('Coloc.', 'Numero', 'Nome', 'Id.', 'Fx.Et.', 'Cl.Fx.', 'Sx.', 'C.', 'Equipe', 'Tempo')
#   - TBH Esportes/corridas_2026_completo_final/2026-03-15_Corrida_VÖRR_2026_15km-masculino.pdf
#   - TBH Esportes/corridas_2026_completo_final/2026-03-29_Corrida_Supermercados_BH_2026_MASCULINO-17.8KM.pdf
#
# === Tipo 3 (3 arquivos) ===
# Cabeçalho: ('Coloc.', 'Número', 'Nome', 'Id.', 'Faixa', 'C.F.', 'Equipe', 'Corrida', 'Ciclismo', 'Corrida', 'Tempo')
#   - TBH Esportes/corridas_2026_completo_final/2026-05-03_Corrida_do_América_2026_GERAL-DUATLHON-REVEZAMENTO.pdf
#   - TBH Esportes/corridas_2026_completo_final/2026-05-03_Corrida_do_América_2026_GERAL-DUATLHON-SIMPLES-FEMININO.pdf
#   - TBH Esportes/corridas_2026_completo_final/2026-05-03_Corrida_do_América_2026_GERAL-DUATLHON-SIMPLES-MASCULINO-1.pdf

# %%
#08/05
standard_header = (
    'Coloc.', 'Num.', 'Nome', 'Sx.', 'Idd.', 'Faixa', 'Cl.Fx.', 'Equipe', 'Tempo', 'Liquido'
)

# %%
#08/05
current_header_tipo2 = (
    'Coloc.', 'Numero', 'Nome', 'Id.', 'Fx.Et.', 'Cl.Fx.', 'Sx.', 'C.', 'Equipe', 'Tempo'
)

# %%
#14/05
def is_tipo2(df):
    primeira_linha = df.iloc[0].astype(str).str.upper().tolist()

    palavras_chave = ['COLOC', 'NUM', 'NOME']

    return all(any(p in col for col in primeira_linha) for p in palavras_chave)

# %%
#14/05
def normalize_tipo2(df_bruto):
    df = df_bruto.copy()

    # Remove cabeçalho
    df = df.iloc[1:].reset_index(drop=True)

    normalized_df = pd.DataFrame()

    normalized_df['Coloc.'] = df[0]
    normalized_df['Num.']   = df[1]
    normalized_df['Nome']   = df[2]
    normalized_df['Sx.']    = df[3]
    normalized_df['Idd.']   = df[4]
    normalized_df['Faixa']  = df[5]
    normalized_df['Cl.Fx.'] = df[6]
    normalized_df['Equipe'] = df[7]
    normalized_df['Tempo']  = df[8]
    normalized_df['Liquido'] = df[9]

    # Limpeza
    normalized_df['Nome'] = (
        normalized_df['Nome']
        .astype(str)
        .str.replace('\n', ' ', regex=False)
        .str.strip()
    )

    return normalized_df

# %%
#14/05
def processar_pdf(key):
    obj = s3.get_object(Bucket=bucket, Key=key)
    pdf_bytes = obj["Body"].read()

    tables = camelot.read_pdf(io.BytesIO(pdf_bytes), flavor='lattice')

    if len(tables) == 0:
        tables = camelot.read_pdf(io.BytesIO(pdf_bytes), flavor='stream')

    if len(tables) == 0:
        raise Exception("Nenhuma tabela encontrada")

    df_bruto = tables[0].df

    # 🔥 Detecta tipo automaticamente
    if is_tipo2(df_bruto):
        df_final = normalize_tipo2(df_bruto)
    else:
        raise Exception("Não é tipo 2")

    return df_final

# %%
resultados = []
erros = []

total = len(pdf_keys)

for i, key in enumerate(pdf_keys, start=1):
    if i % 5 == 0 or i == total:
        print(f"📄 {i}/{total}")

    try:
        df = processar_pdf(key)
        df["arquivo"] = key
        resultados.append(df)

    except Exception as e:
        erros.append({
            "arquivo": key,
            "erro": str(e)
        })

print("\n✅ Processamento finalizado!")
print(f"✔ Sucesso: {len(resultados)} arquivos")
print(f"❌ Erros: {len(erros)} arquivos")
# Out:
# 📄 5/117
# 📄 10/117
# 📄 15/117
# 📄 20/117
# 📄 25/117
# 📄 30/117
# 📄 35/117
# 📄 40/117
# 📄 45/117
# 📄 50/117
# 📄 55/117
# 📄 60/117
# 📄 65/117
# 📄 70/117
# 📄 75/117
# 📄 80/117
# 📄 85/117
# 📄 90/117
# 📄 95/117
# 📄 100/117
# 📄 105/117
# 📄 110/117
# 📄 115/117
# 📄 117/117
#
# ✅ Processamento finalizado!
# ✔ Sucesso: 110 arquivos
# ❌ Erros: 7 arquivos

# %%
df_erros = pd.DataFrame(erros)
display(df_erros)
# Out:
#                                                                                                                         arquivo          erro
# 0                             TBH Esportes/corridas_2026_completo_final/2026-03-15_Corrida_Divas_na_Pista_2026_5KM-FEMININO.pdf  Não é tipo 2
# 1  TBH Esportes/corridas_2026_completo_final/2026-04-12_Corrida_Farid_2026_-_Etapa_Ouro_Branco_COLABORADORES-10KM-MASCULINO.pdf  Não é tipo 2
# 2   TBH Esportes/corridas_2026_completo_final/2026-04-12_Corrida_Farid_2026_-_Etapa_Ouro_Branco_COLABORADORES-5KM-MASCULINO.pdf  Não é tipo 2
# 3                   TBH Esportes/corridas_2026_completo_final/2026-05-03_Corrida_do_América_2026_GERAL-DUATLHON-REVEZAMENTO.pdf  Não é tipo 2
# 4              TBH Esportes/corridas_2026_completo_final/2026-05-03_Corrida_do_América_2026_GERAL-DUATLHON-SIMPLES-FEMININO.pdf  Não é tipo 2
# 5           TBH Esportes/corridas_2026_completo_final/2026-05-03_Corrida_do_América_2026_GERAL-DUATLHON-SIMPLES-MASCULINO-1.pdf  Não é tipo 2
# 6                          TBH Esportes/corridas_2026_completo_final/2026-05-03_Corrida_do_América_2026_GERAL-FEMININO-15KM.pdf  Não é tipo 2

# %%
#18/05
def remover_cabecalho_duplicado(df):
    return df[df[0] != 'Coloc.'].reset_index(drop=True)

# %%
#18/05
key_teste = "TBH Esportes/corridas_2026_completo_final/2026-01-25_Park_Run_2026_06KM-FEMININO-1.pdf"

def processar_tipo1_teste(key, bucket):
    print(f"📄 Processando arquivo:\n{key}\n")

    obj = s3.get_object(Bucket=bucket, Key=key)
    pdf_bytes = obj["Body"].read()

    # 🔥 Lê todas as páginas
    tables = camelot.read_pdf(io.BytesIO(pdf_bytes), pages='all', flavor='lattice')

    if len(tables) == 0:
        print("⚠️ Tentando com stream...")
        tables = camelot.read_pdf(io.BytesIO(pdf_bytes), pages='all', flavor='stream')

    if len(tables) == 0:
        raise Exception("❌ Nenhuma tabela encontrada")

    print(f"✅ Tabelas encontradas: {len(tables)}\n")

    dfs = []

    for i, table in enumerate(tables):
        df = table.df
        print(f"➡️ Página {i+1} - shape: {df.shape}")

        # 🔥 Remove cabeçalho duplicado
        df = df[df[0] != 'Coloc.']

        dfs.append(df)

    # 🔗 Junta tudo
    df_full = pd.concat(dfs, ignore_index=True)

    print("\n🧾 Preview bruto consolidado:")
    display(df_full.head())

    # Remove primeira linha (cabeçalho original)
    df_full = df_full.iloc[1:].reset_index(drop=True)

    # 🔥 Normalização por posição
    df_final = pd.DataFrame()

    df_final['Coloc.'] = df_full[0]
    df_final['Num.']   = df_full[1]
    df_final['Nome']   = df_full[2]
    df_final['Sx.']    = df_full[3]
    df_final['Idd.']   = df_full[4]
    df_final['Faixa']  = df_full[5]
    df_final['Cl.Fx.'] = df_full[6]
    df_final['Equipe'] = df_full[7]
    df_final['Tempo']  = df_full[8]
    df_final['Liquido'] = df_full[9]

    # 🧹 Limpeza
    for col in df_final.columns:
        df_final[col] = (
            df_final[col]
            .astype(str)
            .str.replace('\n', ' ', regex=False)
            .str.strip()
        )

    # ❌ Remove linhas vazias
    df_final = df_final[df_final['Nome'] != '']

    # 🧠 METADADOS
    df_final['arquivo'] = key

      # Data
    match = re.search(r'\d{4}-\d{2}-\d{2}', key)
    df_final['data_evento'] = match.group(0) if match else None

    # Nome da prova
    nome_arquivo = key.split("/")[-1].replace(".pdf", "")
    df_final['nome_prova'] = nome_arquivo

    # Distância (ex: 06KM)
    match_km = re.search(r'(\d{2})KM', key.upper())
    df_final['distancia_km'] = match_km.group(1) if match_km else None

    # Categoria (MASCULINO / FEMININO)
    if "FEMININO" in key.upper():
        df_final['categoria'] = "FEMININO"
    elif "MASCULINO" in key.upper():
        df_final['categoria'] = "MASCULINO"
    else:
        df_final['categoria'] = None

    print("\n🧾 Preview final:")
    display(df_final.head())

    print("\n📊 Linhas finais:", len(df_final))

    return df_final

# %%
#20/05
import io
import re
import boto3
import pandas as pd
import numpy as np
import camelot

S3_BUCKET_RAW = 'tbh-resultados-raw'
S3_BUCKET_SILVER = 'tbh-resultados-silver'

s3_client = boto3.client('s3')

# Cabeçalho padrão
STANDARD_HEADER = ['Coloc.', 'Num.', 'Nome', 'Sx.', 'Idd.', 'Faixa', 'Cl.Fx.', 'Equipe', 'Tempo', 'Liquido']

def extrair_metadados_from_key(key: str):
    filename = os.path.basename(key).replace('.pdf', '')

    data_match = re.search(r'\d{4}-\d{2}-\d{2}', filename)
    data = data_match.group(0) if data_match else None

    corrida_match = re.search(r'\d{4}-\d{2}-\d{2}_(.+?)_\d{4}', filename)
    corrida = corrida_match.group(1) if corrida_match else None

    # Padrões de genero + distância
    pattern1 = r'(?P<dist>\d+(?:\.\d+)?)KM-(?P<gen>FEMININO|MASCULINO)'
    pattern2 = r'(?P<gen>FEMININO|MASCULINO)-(?P<dist>\d+(?:\.\d+)?)KM'

    m = re.search(pattern1, filename, re.IGNORECASE) or re.search(pattern2, filename, re.IGNORECASE)
    if m:
        genero = m.group('gen').upper()
        distancia = float(m.group('dist'))
    else:
        genero = None
        distancia = None

    return {
        'data': data,
        'corrida': corrida,
        'genero': genero,
        'distancia_km': distancia,
        'arquivo': filename + '.pdf',
    }

def is_tipo2(df_raw: pd.DataFrame) -> bool:
    primeira_linha = df_raw.iloc[0].astype(str).str.upper().tolist()
    palavras_chave = ['COLOC', 'NUM', 'NOME']
    return all(any(p in col for col in primeira_linha) for p in palavras_chave)

def header_tuple(df_raw: pd.DataFrame):
    return tuple(df_raw.iloc[0].astype(str).str.strip().tolist())



def normalize_tipo1(df_raw: pd.DataFrame) -> pd.DataFrame:
    """
    Normaliza o DataFrame mantendo a primeira linha de cabeçalho
    e removendo apenas as repetições subsequentes.
    """
    if df_raw.empty:
        return df_raw

    df = df_raw.copy()

    # Padroniza as colunas para índices numéricos para evitar erros de referência
    df.columns = range(df.shape[1])

    # Lógica Sênior: Criamos uma máscara que mantém a linha 0
    # OU qualquer linha onde a coluna 2 não seja o cabeçalho duplicado 'Nome'
    mask = (df.index == df.index[0]) | (df[2] != 'Nome')

    return df[mask].reset_index(drop=True)



######## - PARTE RETIRADA
#def normalize_tipo1(df_raw: pd.DataFrame) -> pd.DataFrame:
    # Remove linhas duplicadas de cabeçalho e a primeira linha (cabeçalho)
    #df = df_raw.copy()
     # 🔥 Garante que estamos trabalhando só com índices numéricos
    #df.columns = range(df.shape[1])

    # 🔥 Remove linhas que são cabeçalho duplicado
    #df = df[df[2] != 'Nome']  # coluna Nome identifica header

    # 🔥 Reset index
    #df = df.reset_index(drop=True)
##########################################

    # Mapear colunas
    out = pd.DataFrame()
    out['Coloc.']  = df[0]
    out['Num.']    = df[1]
    out['Nome']    = df[2]
    out['Sx.']     = df[6]
    out['Idd.']    = df[3]
    out['Faixa']   = df[4]
    out['Cl.Fx.']  = df[5]
    out['Equipe']  = df[8]
    out['Tempo']   = df[9]
    out['Liquido'] = ''

    # Limpeza
    out = out.apply(lambda s: s.astype(str).str.replace('\n', ' ', regex=False).str.strip())

    # Remove linhas inválidas
    out = out[out['Nome'] != '']

    return out

    out = out.apply(lambda s: s.astype(str).str.replace('\n', ' ', regex=False).str.strip())
    # remove linhas sem nome
    out = out[out['Nome'] != '']
    return out

def normalize_tipo2(df_raw: pd.DataFrame) -> pd.DataFrame:
    # Remove a primeira linha (cabeçalho original)
    df = df_raw.copy().iloc[1:].reset_index(drop=True)

    # Mapear colunas do Tipo 2 para padrão
    # Cabeçalho tipo 2 observado:
    # ('Coloc.', 'Numero', 'Nome', 'Id.', 'Fx.Et.', 'Cl.Fx.', 'Sx.', 'C.', 'Equipe', 'Tempo')
    out = pd.DataFrame()
    out['Coloc.']  = df[0]
    out['Num.']    = df[1]  # 'Numero' -> 'Num.'
    out['Nome']    = df[2]
    out['Sx.']     = df[6]  # 'Sx.' está na 6 no tipo2
    out['Idd.']    = df[3]  # 'Id.' -> 'Idd.'
    out['Faixa']   = df[4]  # 'Fx.Et.' -> 'Faixa'
    out['Cl.Fx.']  = df[5]
    out['Equipe']  = df[8]
    out['Tempo']   = df[9]
    out['Liquido'] = ''     # tipo 2 não tem 'Liquido' -> preencher vazio

    out = out.apply(lambda s: s.astype(str).str.replace('\n', ' ', regex=False).str.strip())
    out = out[out['Nome'] != '']
    return out

def add_metadados(df_padrao: pd.DataFrame, key: str) -> pd.DataFrame:
    meta = extrair_metadados_from_key(key)
    for k, v in meta.items():
        df_padrao[k] = v
    return df_padrao

def coerce_types(df: pd.DataFrame) -> pd.DataFrame:
    # Colunas numéricas básicas quando possível
    for col in ['Coloc.', 'Num.', 'Idd.']:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors='coerce')
    # Mantém Tempo/Liquido como string (podem ser hh:mm:ss)
    return df

def salvar_parquet_s3(df: pd.DataFrame, bucket: str, key_out: str):
    # Usa buffer em memória e faz upload via boto3
    buf = io.BytesIO()
    df.to_parquet(buf, index=False)
    buf.seek(0)
    s3_client.put_object(Bucket=bucket, Key=key_out, Body=buf.getvalue(), ContentType='application/octet-stream')

# %%
#02/06

def fix_shifted_rows(df):
    """
    Corrige o problema de colunas fundidas (ex: '1 1639') comum em extrações de PDF.
    """
    new_rows = []
    for _, row in df.iterrows():
        row_list = [str(v).strip() if pd.notna(v) else "" for v in row]
        # Se a primeira coluna tem dois números separados por espaço, separa-os
        if re.match(r'^\d+\s+\d+$', row_list[0]):
            parts = row_list[0].split()
            row_list = [parts[0], parts[1]] + row_list[1:-1]
        # Se a primeira é vazia e a segunda tem dois números
        elif row_list[0] == "" and len(row_list) > 1 and re.match(r'^\d+\s+\d+$', row_list[1]):
            parts = row_list[1].split()
            row_list = [parts[0], parts[1]] + row_list[2:]
        new_rows.append(row_list)

    # Garantir que o número de colunas do DataFrame resultante corresponda ao esperado
    return pd.DataFrame(new_rows)

def find_header_and_data_start(df, expected_headers, max_rows_to_check=15):
    """
    Procura o cabeçalho no DataFrame, ignorando colunas vazias à direita que podem
    ser geradas na extração do PDF.
    """
    for i in range(min(max_rows_to_check, len(df))):
        # Pega os valores da linha e remove espaços
        row_vals = [str(x).strip() for x in df.iloc[i].tolist()]

        # Remove strings vazias do final da lista (comum em extrações 'stream' do Camelot)
        while row_vals and row_vals[-1] == "":
            row_vals.pop()

        row_tuple = tuple(row_vals)

        for h in expected_headers:
            # Compara a tupla encontrada com o cabeçalho esperado
            if row_tuple == h:
                return i, h
    return -1, None

def normalize_dataframe(df_raw, detected_header_tuple, header_row_index):
    """
    Normaliza o DataFrame a partir do cabeçalho detectado.
    """
    if header_row_index == -1: return pd.DataFrame()

    # 1. Corta o DataFrame a partir do cabeçalho
    df_norm = df_raw.iloc[header_row_index:].reset_index(drop=True)

    # 2. Ajusta as colunas para bater com o tamanho do cabeçalho detectado
    num_cols_expected = len(detected_header_tuple)
    df_norm = df_norm.iloc[:, :num_cols_expected]

    # Define nomes temporários para as colunas
    df_norm.columns = [f"col_{i}" for i in range(df_norm.shape[1])]

    # 3. Corrige linhas deslocadas
    df_norm = fix_shifted_rows(df_norm)

    # Redefine colunas após fix_shifted_rows para garantir o tamanho correto
    df_norm = df_norm.iloc[:, :num_cols_expected]

    h1 = ('Coloc.', 'Num.', 'Nome', 'Sx.', 'Idd.', 'Faixa', 'Cl.Fx.', 'Equipe', 'Tempo', 'Liquido')
    h2 = ('Coloc.', 'Numero', 'Nome', 'Id.', 'Fx.Et.', 'Cl.Fx.', 'Sx.', 'C.', 'Equipe', 'Tempo')

    mapping = {
        h1: ['colocacao', 'numero', 'nome', 'sexo', 'idade', 'faixa', 'class_fx', 'equipe', 'tempo', 'liquido'],
        h2: ['colocacao', 'numero', 'nome', 'idade', 'faixa', 'class_fx', 'sexo', 'c', 'equipe', 'tempo']
    }

    df_norm.columns = mapping.get(detected_header_tuple, [f"col_{i}" for i in range(df_norm.shape[1])])

    # 4. Limpeza final
    header_vals = ['Coloc.', 'Num.', 'Numero']
    df_norm = df_norm[~df_norm['colocacao'].isin(header_vals)].reset_index(drop=True)

    # Remove linhas onde o nome está vazio
    if 'nome' in df_norm.columns:
        df_norm = df_norm.replace(r'^\s*$', pd.NA, regex=True).dropna(subset=['nome'], how='all').reset_index(drop=True)

    return df_norm

def extrair_metadados_from_key(key_pdf):
    filename = os.path.basename(key_pdf)

    # 1. Gênero
    genero = "NA"
    if "FEMININO" in filename.upper(): genero = "FEMININO"
    elif "MASCULINO" in filename.upper(): genero = "MASCULINO"

    # 2. Distância
    dist_match = re.search(r'(\d+)\s*KM', filename, re.IGNORECASE)
    distancia = dist_match.group(1) if dist_match else "NA"

    # 3. Data
    data = "NA"
    data_match = re.search(r'(\d{4}-\d{2}-\d{2})', filename)
    if data_match: data = data_match.group(1)

    # 4. Nome da Corrida
    base = filename.rsplit('.', 1)[0].lower()
    nome_corrida = "Desconhecida"

    if "bonissima" in base: nome_corrida = "Boníssima Run"
    elif "supermercado_bh" in base: nome_corrida = "Supermercado BH"
    elif "o_tempo" in base: nome_corrida = "Corrida O Tempo"
    elif "park_run" in base: nome_corrida = "Park Run"
    elif data != "NA":
        parts = re.split(r'\d{4}-\d{2}-\d{2}_', filename)
        if len(parts) > 1:
            nome_part = re.split(r'(_GERAL|_FEMININO|_MASCULINO|_\d+KM)', parts[1], flags=re.IGNORECASE)[0]
            nome_corrida = nome_part.replace('_', ' ').strip().title()
    else:
        clean = re.sub(r'^-?\d+-', '', base)
        clean = re.sub(r'(geral|feminino|masculino|\d+km).*', '', clean, flags=re.IGNORECASE)
        nome_corrida = clean.replace('_', ' ').replace('-', ' ').strip().title()

    return {
        'data': data,
        'corrida': nome_corrida,
        'genero': genero,
        'distancia_km': distancia
    }

def processar_pdf_para_parquet(key_pdf, bucket_raw, bucket_silver):
    """
    Função principal ajustada.
    """
    obj = s3_client.get_object(Bucket=bucket_raw, Key=key_pdf)
    pdf_bytes = obj['Body'].read()

    h1 = ('Coloc.', 'Num.', 'Nome', 'Sx.', 'Idd.', 'Faixa', 'Cl.Fx.', 'Equipe', 'Tempo', 'Liquido')
    h2 = ('Coloc.', 'Numero', 'Nome', 'Id.', 'Fx.Et.', 'Cl.Fx.', 'Sx.', 'C.', 'Equipe', 'Tempo')

    # Tenta extração por lattice (tabelas com bordas) e depois stream (texto alinhado)
    tables = camelot.read_pdf(io.BytesIO(pdf_bytes), pages='all', flavor='lattice')
    if not tables:
        tables = camelot.read_pdf(io.BytesIO(pdf_bytes), pages='all', flavor='stream')

    if not tables:
        return {'arquivo': key_pdf, 'status': 'erro', 'motivo': 'Sem tabelas'}

    dfs = [t.df for t in tables]

    # O ajuste principal foi na find_header_and_data_start para ser resiliente a colunas vazias
    idx, header_tipo = find_header_and_data_start(dfs[0], [h1, h2])

    if not header_tipo:
        return {'arquivo': key_pdf, 'status': 'erro', 'motivo': 'Cabeçalho desconhecido'}

    df_full = pd.concat(dfs, ignore_index=True)
    df_final = normalize_dataframe(df_full, header_tipo, idx)

    # Aplica Metadados
    meta = extrair_metadados_from_key(key_pdf)
    df_final['corrida'] = meta['corrida']
    df_final['genero'] = meta['genero']
    df_final['distancia_km'] = meta['distancia_km']
    df_final['arquivo'] = os.path.basename(key_pdf)

    # Tipagem e Metadados Adicionais (Mantendo chamadas originais)
    df_final = add_metadados(df_final, key_pdf)
    df_final = coerce_types(df_final)

    # Exportação
    file_name = os.path.basename(key_pdf).replace(".pdf", ".parquet")
    data_part = meta.get('data', 'sem_data')
    path_out = f"TBH Esportes/corridas_2026_silver/data={data_part}/{file_name}"

    salvar_parquet_s3(df_final, bucket_silver, path_out)
    return {'arquivo': key_pdf, 'status': 'ok', 'linhas': len(df_final)}

# %%
bucket = S3_BUCKET_RAW
prefix = "TBH Esportes/corridas_2026_completo_final/"

# Lista todos os arquivos do prefixo
pdf_keys = listar_arquivos_s3(s3_client, bucket, prefix)

print(f"Total de arquivos encontrados: {len(pdf_keys)}")
for k in pdf_keys:
    print(f" - {k}")

resultados = []

for key in tqdm(pdf_keys, desc='Processando todos os arquivos'):

    # ignora possíveis "pastas"
    if key.endswith('/'):
        continue

    try:
        info = processar_pdf_para_parquet(
            key_pdf=key,
            bucket_raw=S3_BUCKET_RAW,
            bucket_silver=S3_BUCKET_SILVER
        )
        resultados.append(info)

    except Exception as e:
        print(f"Erro ao processar {key}: {e}")
        resultados.append({
            "arquivo": key,
            "status": "erro",
            "mensagem": str(e)
        })

df_resultados = pd.DataFrame(resultados)

if not df_resultados.empty:
    display(df_resultados)
    print("\nResumo do processamento:")
    print(df_resultados['status'].value_counts(dropna=False))
else:
    print("\nNenhum arquivo encontrado no prefixo.")
# Out:
# Total de arquivos encontrados: 117
#  - TBH Esportes/corridas_2026_completo_final/2026-01-25_Park_Run_2026_06KM-FEMININO-1.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-01-25_Park_Run_2026_06KM-MASCULINO.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-01-25_Park_Run_2026_09KM-FEMININO.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-01-25_Park_Run_2026_09KM-MASCULINO.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-02-01_Ouro_Verde_Run_2026_FEMININO-12.8KM-1.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-02-01_Ouro_Verde_Run_2026_FEMININO-6.4KM-2.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-02-01_Ouro_Verde_Run_2026_MASCULINO-12.8KM-2.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-02-01_Ouro_Verde_Run_2026_MASCULINO-6.4KM-1.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-02-08_Corrida_do_GER_2026_10KM-FEMININO-MILITAR.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-02-08_Corrida_do_GER_2026_10KM-FEMININO-PUBLICO-GERAL-1.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-02-08_Corrida_do_GER_2026_10KM-MACULINO-MILITAR.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-02-08_Corrida_do_GER_2026_10KM-MASCULINO-PUBLICO-GERAL-1.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-02-08_Corrida_do_GER_2026_5KM-FEMININO-MILITAR.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-02-08_Corrida_do_GER_2026_5KM-FEMININO-PUBLICO-GERAL-1.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-02-08_Corrida_do_GER_2026_5KM-MASCULINO-MILITAR.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-02-08_Corrida_do_GER_2026_5KM-MASCULINO-PUBLICO-GERAL-1.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-02-22_Corrida_Italiana_do_Cruzeiro_2026_GERAL-FEMININO-10KM-1.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-02-22_Corrida_Italiana_do_Cruzeiro_2026_GERAL-FEMININO-5KM-1.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-02-22_Corrida_Italiana_do_Cruzeiro_2026_GERAL-MASCULINO-10KM-1.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-02-22_Corrida_Italiana_do_Cruzeiro_2026_GERAL-MASCULINO-5KM-1.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-02-22_Corrida_Mano_Down_2026_10km-feminino-1.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-02-22_Corrida_Mano_Down_2026_10km-masculino-1.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-02-22_Corrida_Mano_Down_2026_5km-feminino-1.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-02-22_Corrida_Mano_Down_2026_5km-masculino-1.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-01_Boníssima_Run_GERAL-FEMININO-10KM-6.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-01_Boníssima_Run_GERAL-FEMININO-21KM-3.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-01_Boníssima_Run_GERAL-FEMININO-5KM-6.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-01_Boníssima_Run_GERAL-MASCULINO-10KM-7.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-01_Boníssima_Run_GERAL-MASCULINO-21KM-2.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-01_Boníssima_Run_GERAL-MASCULINO-5KM-7.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-08_Circuito_Planet_Run_Marjan_Farma_2026_-_Etapa_África_do_Sul_10KM-FEMININO.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-08_Circuito_Planet_Run_Marjan_Farma_2026_-_Etapa_África_do_Sul_10KM-MASCULINO.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-08_Circuito_Planet_Run_Marjan_Farma_2026_-_Etapa_África_do_Sul_5KM-FEMININO-2.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-08_Circuito_Planet_Run_Marjan_Farma_2026_-_Etapa_África_do_Sul_5KM-MASCULINO.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-08_Corrida_do_25º_BPM_GERAL-FEMININO-10KM-MILITAR.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-08_Corrida_do_25º_BPM_GERAL-FEMININO-10KM.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-08_Corrida_do_25º_BPM_GERAL-FEMININO-5KM-MILITAR.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-08_Corrida_do_25º_BPM_GERAL-FEMININO-5KM.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-08_Corrida_do_25º_BPM_GERAL-MASCULINO-10KM-MILITAR.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-08_Corrida_do_25º_BPM_GERAL-MASCULINO-10KM.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-08_Corrida_do_25º_BPM_GERAL-MASCULINO-5KM-MILITAR.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-08_Corrida_do_25º_BPM_GERAL-MASCULINO-5KM.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-15_Corrida_Divas_na_Pista_2026_5KM-FEMININO.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-15_Corrida_VÖRR_2026_10km-feminino.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-15_Corrida_VÖRR_2026_10km-masculino.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-15_Corrida_VÖRR_2026_15km-feminino.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-15_Corrida_VÖRR_2026_15km-masculino.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-15_Corrida_VÖRR_2026_5km-feminino.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-15_Corrida_VÖRR_2026_5km-masculino.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-22_5ª_Corrida_Contagem_Por_Todas_2026_10KM.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-22_5ª_Corrida_Contagem_Por_Todas_2026_5KM.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-22_Corrida_do_Bope_2026_10KM-FEMININO-GERAL-4.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-22_Corrida_do_Bope_2026_10KM-FEMININO-MILITAR-2.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-22_Corrida_do_Bope_2026_10KM-MASCULINO-GERAL-3.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-22_Corrida_do_Bope_2026_10KM-MASCULINO-MILITAR-2.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-22_Corrida_do_Bope_2026_18KM-FEMININO-GERAL.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-22_Corrida_do_Bope_2026_18KM-FEMININO-MILITAR.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-22_Corrida_do_Bope_2026_18KM-MASCULINO-GERAL.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-22_Corrida_do_Bope_2026_18KM-MASCULINO-MILITAR.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-22_Corrida_do_Bope_2026_5KM-FEMININO-GERAL-4.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-22_Corrida_do_Bope_2026_5KM-FEMININO-MILITAR-2.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-22_Corrida_do_Bope_2026_5KM-MASCULINO-GERAL-4.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-22_Corrida_do_Bope_2026_5KM-MASCULINO-MILITAR-2.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-29_Corrida_Supermercados_BH_2026_FEMININO-10KM.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-29_Corrida_Supermercados_BH_2026_FEMININO-17.8KM.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-29_Corrida_Supermercados_BH_2026_FEMININO-5KM.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-29_Corrida_Supermercados_BH_2026_MASCULINO-10KM.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-29_Corrida_Supermercados_BH_2026_MASCULINO-17.8KM.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-03-29_Corrida_Supermercados_BH_2026_MASCULINO-5KM.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-12_Corrida_Farid_2026_-_Etapa_Ouro_Branco_COLABORADORES-10KM-MASCULINO.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-12_Corrida_Farid_2026_-_Etapa_Ouro_Branco_COLABORADORES-5KM-FEMININO.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-12_Corrida_Farid_2026_-_Etapa_Ouro_Branco_COLABORADORES-5KM-MASCULINO.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-12_Corrida_Farid_2026_-_Etapa_Ouro_Branco_GERAL-10KM-FEMININO.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-12_Corrida_Farid_2026_-_Etapa_Ouro_Branco_GERAL-10KM-MASCULINO.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-12_Corrida_Farid_2026_-_Etapa_Ouro_Branco_GERAL-5KM-FEMININO.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-12_Corrida_Farid_2026_-_Etapa_Ouro_Branco_GERAL-5KM-MASCULINO.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-12_Corrida_Rotam_2026_GERAL_10KM_FEMININO.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-12_Corrida_Rotam_2026_GERAL_10KM_MASCULINO.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-12_Corrida_Rotam_2026_GERAL_5KM_FEMININO.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-12_Corrida_Rotam_2026_GERAL_5KM_MASCULINO.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-12_Corrida_Rotam_2026_MILITAR_10KM_FEMININO.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-12_Corrida_Rotam_2026_MILITAR_10KM_MASCULINO.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-12_Corrida_Rotam_2026_MILITAR_5KM_FEMININO.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-12_Corrida_Rotam_2026_MILITAR_5KM_MASCULINO.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-19_Corrida_SuperLuna_2026_10KM-FEMININO.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-19_Corrida_SuperLuna_2026_10KM-MASCULINO.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-19_Corrida_SuperLuna_2026_6KM-FEMININO.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-19_Corrida_SuperLuna_2026_6KM-MASCULINO.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-26_Corrida_Sest_Senat_e_Você_2026_10km-feminino.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-26_Corrida_Sest_Senat_e_Você_2026_10km-masculino.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-26_Corrida_Sest_Senat_e_Você_2026_5km-feminino.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-26_Corrida_Sest_Senat_e_Você_2026_5km-masculino.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-26_Corrida_Supermercados_BH_2026_-_ETAPA_UBERLÂNDIA_GERAL-FEMININO-10KM.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-26_Corrida_Supermercados_BH_2026_-_ETAPA_UBERLÂNDIA_GERAL-FEMININO-5KM.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-26_Corrida_Supermercados_BH_2026_-_ETAPA_UBERLÂNDIA_GERAL-MASCULINO-10KM.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-26_Corrida_Supermercados_BH_2026_-_ETAPA_UBERLÂNDIA_GERAL-MASCULINO-5KM.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-26_Corrida_do_Exercito_2026_10km-feminino-geral.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-26_Corrida_do_Exercito_2026_10km-feminino-militar.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-26_Corrida_do_Exercito_2026_10km-geral-masculino.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-26_Corrida_do_Exercito_2026_10km-masculino-militar.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-26_Corrida_do_Exercito_2026_5km-feminino-geral.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-26_Corrida_do_Exercito_2026_5km-feminino-militar.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-26_Corrida_do_Exercito_2026_5km-masculino-geral.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-26_Corrida_do_Exercito_2026_5km-masculino-militar.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-05-03_Corrida_do_América_2026_GERAL-DUATLHON-REVEZAMENTO.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-05-03_Corrida_do_América_2026_GERAL-DUATLHON-SIMPLES-FEMININO.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-05-03_Corrida_do_América_2026_GERAL-DUATLHON-SIMPLES-MASCULINO-1.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-05-03_Corrida_do_América_2026_GERAL-FEMININO-10KM.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-05-03_Corrida_do_América_2026_GERAL-FEMININO-15KM.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-05-03_Corrida_do_América_2026_GERAL-FEMININO-5KM.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-05-03_Corrida_do_América_2026_GERAL-MASCULINO-10KM.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-05-03_Corrida_do_América_2026_GERAL-MASCULINO-15KM.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-05-03_Corrida_do_América_2026_GERAL-MASCULINO-5KM.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-05-03_corridaotempo_10KM_FEMININO.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-05-03_corridaotempo_10KM_MASCULINO.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-05-03_corridaotempo_5KM_FEMININO.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-05-03_corridaotempo_5KM_MASCULINO.pdf
# Processando todos os arquivos: 100%|██████████| 117/117 [1:11:01<00:00, 36.43s/it]
#                                                                                                   arquivo status  linhas motivo
# 0                  TBH Esportes/corridas_2026_completo_final/2026-01-25_Park_Run_2026_06KM-FEMININO-1.pdf     ok   860.0    NaN
# 1                   TBH Esportes/corridas_2026_completo_final/2026-01-25_Park_Run_2026_06KM-MASCULINO.pdf     ok   400.0    NaN
# 2                    TBH Esportes/corridas_2026_completo_final/2026-01-25_Park_Run_2026_09KM-FEMININO.pdf     ok   286.0    NaN
# 3                   TBH Esportes/corridas_2026_completo_final/2026-01-25_Park_Run_2026_09KM-MASCULINO.pdf     ok   257.0    NaN
# 4          TBH Esportes/corridas_2026_completo_final/2026-02-01_Ouro_Verde_Run_2026_FEMININO-12.8KM-1.pdf     ok    91.0    NaN
# ..                                                                                                    ...    ...     ...    ...
# 112  TBH Esportes/corridas_2026_completo_final/2026-05-03_Corrida_do_América_2026_GERAL-MASCULINO-5KM.pdf     ok   222.0    NaN
# 113                  TBH Esportes/corridas_2026_completo_final/2026-05-03_corridaotempo_10KM_FEMININO.pdf     ok   110.0    NaN
# 114                 TBH Esportes/corridas_2026_completo_final/2026-05-03_corridaotempo_10KM_MASCULINO.pdf     ok   167.0    NaN
# 115                   TBH Esportes/corridas_2026_completo_final/2026-05-03_corridaotempo_5KM_FEMININO.pdf     ok   826.0    NaN
# 116                  TBH Esportes/corridas_2026_completo_final/2026-05-03_corridaotempo_5KM_MASCULINO.pdf     ok   510.0    NaN
#
# [117 rows x 4 columns]
# Resumo do processamento:
# status
# ok      113
# erro      4
# Name: count, dtype: int64

# %%
#22/05 - PARA TESTAR ARQUIVOS ESPECIFICOS

bucket = S3_BUCKET_RAW
prefix = "TBH Esportes/corridas_2026_completo_final/"

# Lista todos os arquivos do prefixo
pdf_keys_all = listar_arquivos_s3(s3_client, bucket, prefix)

# FILTRO: Seleciona apenas os arquivos que você deseja testar
# O filtro busca por qualquer parte do nome para ser mais flexível
arquivos_teste = [
    "2026-04-12_Corrida_Farid",
    #"2026-03-01_Boníssima_Run"

]

pdf_keys = [
    key for key in pdf_keys_all
    if any(nome_teste.lower() in key.lower() for nome_teste in arquivos_teste)
]

print(f"Arquivos encontrados para teste: {len(pdf_keys)}")
for k in pdf_keys: print(f" - {k}")

resultados = []
# Agora o loop rodará apenas para os arquivos filtrados
for key in tqdm(pdf_keys, desc='Testando extração específica'):
    info = processar_pdf_para_parquet(
        key_pdf=key,
        bucket_raw=S3_BUCKET_RAW,
        bucket_silver=S3_BUCKET_SILVER
    )
    resultados.append(info)


df_resultados = pd.DataFrame(resultados)
if not df_resultados.empty:
    display(df_resultados)
    print("\nResumo do Teste:")
    print(df_resultados['status'].value_counts(dropna=False))
else:
    print("\nNenhum arquivo encontrado com os nomes especificados. Verifique o prefixo ou os nomes de teste.")
# Out:
# Arquivos encontrados para teste: 7
#  - TBH Esportes/corridas_2026_completo_final/2026-04-12_Corrida_Farid_2026_-_Etapa_Ouro_Branco_COLABORADORES-10KM-MASCULINO.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-12_Corrida_Farid_2026_-_Etapa_Ouro_Branco_COLABORADORES-5KM-FEMININO.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-12_Corrida_Farid_2026_-_Etapa_Ouro_Branco_COLABORADORES-5KM-MASCULINO.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-12_Corrida_Farid_2026_-_Etapa_Ouro_Branco_GERAL-10KM-FEMININO.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-12_Corrida_Farid_2026_-_Etapa_Ouro_Branco_GERAL-10KM-MASCULINO.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-12_Corrida_Farid_2026_-_Etapa_Ouro_Branco_GERAL-5KM-FEMININO.pdf
#  - TBH Esportes/corridas_2026_completo_final/2026-04-12_Corrida_Farid_2026_-_Etapa_Ouro_Branco_GERAL-5KM-MASCULINO.pdf
# Testando extração específica: 100%|██████████| 7/7 [00:46<00:00,  6.66s/it]
#                                                                                                                         arquivo status  linhas
# 0  TBH Esportes/corridas_2026_completo_final/2026-04-12_Corrida_Farid_2026_-_Etapa_Ouro_Branco_COLABORADORES-10KM-MASCULINO.pdf     ok       2
# 1    TBH Esportes/corridas_2026_completo_final/2026-04-12_Corrida_Farid_2026_-_Etapa_Ouro_Branco_COLABORADORES-5KM-FEMININO.pdf     ok       5
# 2   TBH Esportes/corridas_2026_completo_final/2026-04-12_Corrida_Farid_2026_-_Etapa_Ouro_Branco_COLABORADORES-5KM-MASCULINO.pdf     ok       2
# 3           TBH Esportes/corridas_2026_completo_final/2026-04-12_Corrida_Farid_2026_-_Etapa_Ouro_Branco_GERAL-10KM-FEMININO.pdf     ok      65
# 4          TBH Esportes/corridas_2026_completo_final/2026-04-12_Corrida_Farid_2026_-_Etapa_Ouro_Branco_GERAL-10KM-MASCULINO.pdf     ok     105
# 5            TBH Esportes/corridas_2026_completo_final/2026-04-12_Corrida_Farid_2026_-_Etapa_Ouro_Branco_GERAL-5KM-FEMININO.pdf     ok     387
# 6           TBH Esportes/corridas_2026_completo_final/2026-04-12_Corrida_Farid_2026_-_Etapa_Ouro_Branco_GERAL-5KM-MASCULINO.pdf     ok     233
# Resumo do Teste:
# status
# ok    7
# Name: count, dtype: int64
